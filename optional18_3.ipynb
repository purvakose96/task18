# %% [markdown]
# <a href="https://colab.research.google.com/github/purvakose96/task18/blob/main/optional18_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-64dc201e-72f2-478a-8c4a-f9f481980ea5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-64dc201e-72f2-478a-8c4a-f9f481980ea5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filepath = "/content/bikes_data.csv"
df = pd.read_csv(filepath)
df.head(10)
# Out:
#    Company Country of Origin       Model Number of cc Horsepower   Torque  \
# 0  Aprilia             Italy      RS 660          659     100 hp    67 Nm
# 1  Aprilia             Italy   Tuono 660          659     100 hp    67 Nm
# 2  Aprilia             Italy      RS 125        124.9      15 hp    12 Nm
# 3  Aprilia             Italy  Shiver 900          896      95 hp    90 Nm
# 4  Aprilia             Italy  Tuono 1100         1077     175 hp   121 Nm
# 5  Benelli             Italy     TNT 125          125      11 hp  10.8 Nm
# 6  Benelli             Italy     TNT 250          250      27 hp  21.2 Nm
# 7  Benelli             Italy     TNT 300          300      39 hp  26.5 Nm
# 8  Benelli             Italy    TNT 600i          600      85 hp  54.6 Nm
# 9  Benelli             Italy     TNT 899          899     116 hp  86.3 Nm
#
#       Transmission Type Drivetrain  Number of Seating Price (in INR)  Year  \
# 0  6-speed quickshifter      Chain                  2  INR 10,99,000  2021
# ...

# %%
df.tail(5)
# Out:
#                     Company Country of Origin           Model Number of cc  \
# 357  Energica Motor Company             Italy       EsseEsse9       110 kW
# 358  Energica Motor Company             Italy            EGO+       126 kW
# 359  Energica Motor Company             Italy  Eva Ribelle RS       126 kW
# 360             Moto Morini             Italy          X-Cape          649
# 361             Moto Morini             Italy  Seiemmezzo 6 ½          649
#
#     Horsepower     Torque Transmission Type     Drivetrain  Number of Seating  \
# 357     163 hp  195 lb-ft         Automatic       Electric                  2
# 358     171 hp  222 lb-ft         Automatic       Electric                  1
# 359     171 hp  222 lb-ft         Automatic       Electric                  2
# 360    60.8 PS      62 Nm    6-speed manual  Parallel twin                  2
# 361    55.7 PS      58 Nm    6-speed manual  Parallel twin                  2
#
# ...

# %%
df.shape
# Out:
# (362, 15)

# %%
df.columns
# Out:
# Index(['Company', 'Country of Origin', 'Model', 'Number of cc', 'Horsepower',
#        'Torque', 'Transmission Type', 'Drivetrain', 'Number of Seating',
#        'Price (in INR)', 'Year', 'Looks', 'Body Type', 'Engine Type',
#        'Number of Cylinders'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Company                object
# Country of Origin      object
# Model                  object
# Number of cc           object
# Horsepower             object
# Torque                 object
# Transmission Type      object
# Drivetrain             object
# Number of Seating       int64
# Price (in INR)         object
# Year                    int64
# Looks                  object
# Body Type              object
# Engine Type            object
# Number of Cylinders    object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Company                0
# Country of Origin      0
# Model                  0
# Number of cc           0
# Horsepower             0
# Torque                 0
# Transmission Type      0
# Drivetrain             0
# Number of Seating      0
# Price (in INR)         0
# Year                   0
# Looks                  0
# Body Type              0
# Engine Type            0
# Number of Cylinders    1
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (362, 15)

# %%
df.describe()
# Out:
#        Number of Seating         Year
# count         362.000000   362.000000
# mean            1.618785  2021.627072
# std             0.492020     3.691967
# min             1.000000  1994.000000
# 25%             1.000000  2022.000000
# 50%             2.000000  2023.000000
# 75%             2.000000  2023.000000
# max             3.000000  2023.000000

# %%
# Statistical Summary
print(df.describe())

# Mean
print("\nMean")
print(df.mean(numeric_only=True))

# Median
print("\nMedian")
print(df.median(numeric_only=True))

# Minimum
print("\nMinimum")
print(df.min(numeric_only=True))

# Maximum
print("\nMaximum")
print(df.max(numeric_only=True))

# Observation:
# Displays statistical summary of all numerical columns.
# Out:
#        Number of Seating         Year
# count         362.000000   362.000000
# mean            1.618785  2021.627072
# std             0.492020     3.691967
# min             1.000000  1994.000000
# 25%             1.000000  2022.000000
# 50%             2.000000  2023.000000
# 75%             2.000000  2023.000000
# max             3.000000  2023.000000
#
# Mean
# Number of Seating       1.618785
# Year                 2021.627072
# dtype: float64
#
# Median
# Number of Seating       2.0
# Year                 2023.0
# dtype: float64
#
# Minimum
# Number of Seating       1
# Year                 1994
# dtype: int64
#
# Maximum
# Number of Seating       3
# Year                 2023
# dtype: int64

# %%
import matplotlib.pyplot as plt

numeric_cols = df.select_dtypes(include='number').columns

for col in numeric_cols:
    plt.figure(figsize=(5,4))
    plt.hist(df[col], bins=20, edgecolor='black')
    plt.title(col)
    plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Count Plot for Number of Cylinders
plt.figure(figsize=(6,4))
sns.countplot(x='Number of Cylinders', data=df)
plt.title('Count Plot of Number of Cylinders')
plt.xticks(rotation=45)
plt.show()

# Count Plot for Country of Origin
plt.figure(figsize=(8,4))
sns.countplot(x='Country of Origin', data=df)
plt.title('Count Plot of Country of Origin')
plt.xticks(rotation=45)
plt.show()

# Observation:
# The count plots show the frequency distribution of the Number of Cylinders
# and the Country of Origin in the dataset.

# %%
numeric_cols = df.select_dtypes(include='number').columns

plt.figure(figsize=(8,6))

sns.heatmap(df[numeric_cols].corr(),
            annot=True,
            cmap='coolwarm',
            fmt=".2f")

plt.show()

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

print("Independent Features")
print(X.columns)

print("\nDependent Feature")
print(y.name)
# Out:
# Independent Features
# Index(['Company', 'Country of Origin', 'Model', 'Number of cc', 'Horsepower',
#        'Torque', 'Transmission Type', 'Drivetrain', 'Number of Seating',
#        'Price (in INR)', 'Year', 'Looks', 'Body Type', 'Engine Type'],
#       dtype='object')
#
# Dependent Feature
# Number of Cylinders

# %%
X = df.drop('Price (in INR)', axis=1)
y = df['Price (in INR)']

print("Independent Features")
print(X.columns)

print("\nDependent Feature")
print(y.name)
# Out:
# Independent Features
# Index(['Company', 'Country of Origin', 'Model', 'Number of cc', 'Horsepower',
#        'Torque', 'Transmission Type', 'Drivetrain', 'Number of Seating',
#        'Year', 'Looks', 'Body Type', 'Engine Type', 'Number of Cylinders'],
#       dtype='object')
#
# Dependent Feature
# Price (in INR)

# %%
categorical_cols = df.select_dtypes(include='object').columns

df_encoded = pd.get_dummies(df,
                            columns=categorical_cols,
                            drop_first=True)

print(df_encoded.head())
# Out:
#    Number of Seating  Year  Company_Aeon  Company_Ampere  Company_Apollo  \
# 0                  2  2021         False           False           False
# 1                  2  2021         False           False           False
# 2                  2  2022         False           False           False
# 3                  2  2022         False           False           False
# 4                  2  2022         False           False           False
#
#    Company_Aprilia  Company_Arcfox  Company_BMW  Company_Bajaj  \
# 0             True           False        False          False
# 1             True           False        False          False
# 2             True           False        False          False
# 3             True           False        False          False
# 4             True           False        False          False
#
#    Company_Benelli  ...  Number of Cylinders_1  Number of Cylinders_2  \
# 0            False  ...                  False                   True
# ...

# %%
from sklearn.preprocessing import StandardScaler

X = df_encoded.iloc[:, :-1]

numeric_cols = X.select_dtypes(include='number').columns

scaler = StandardScaler()

X[numeric_cols] = scaler.fit_transform(X[numeric_cols])

print(X.head())
# Out:
#    Number of Seating      Year  Company_Aeon  Company_Ampere  Company_Apollo  \
# 0           0.775869 -0.170083         False           False           False
# 1           0.775869 -0.170083         False           False           False
# 2           0.775869  0.101151         False           False           False
# 3           0.775869  0.101151         False           False           False
# 4           0.775869  0.101151         False           False           False
#
#    Company_Aprilia  Company_Arcfox  Company_BMW  Company_Bajaj  \
# 0             True           False        False          False
# 1             True           False        False          False
# 2             True           False        False          False
# 3             True           False        False          False
# 4             True           False        False          False
#
#    Company_Benelli  ...  Engine Type_V4  Number of Cylinders_1  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# Load Dataset
df = pd.read_csv('/content/bikes_data.csv')

# Remove Missing Values & Duplicates
df.drop_duplicates(inplace=True)
df.dropna(inplace=True)

# Histogram
numeric_cols = df.select_dtypes(include='number').columns

for col in numeric_cols:
    plt.figure(figsize=(5,4))
    plt.hist(df[col], bins=20, edgecolor='black')
    plt.title(col)
    plt.show()

# Count Plot
categorical_cols = df.select_dtypes(include='object').columns

for col in categorical_cols:
    plt.figure(figsize=(7,4))
    sns.countplot(x=col, data=df)
    plt.xticks(rotation=45)
    plt.show()

# Heatmap
plt.figure(figsize=(8,6))
sns.heatmap(df[numeric_cols].corr(),
            annot=True,
            cmap='coolwarm',
            fmt=".2f")
plt.show()

# Features
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# Encoding
X = pd.get_dummies(X, drop_first=True)

# Scaling
numeric_cols = X.select_dtypes(include='number').columns

scaler = StandardScaler()
X[numeric_cols] = scaler.fit_transform(X[numeric_cols])

print("Final Preprocessed Data")
print(X.head())

print("\nTarget Variable")
print(y.head())
# Out:
# Final Preprocessed Data
#    Number of Seating     Year  Company_Aeon  Company_Ampere  Company_Apollo  \
# 0           0.773013 -0.16885         False           False           False
# 1           0.773013 -0.16885         False           False           False
# 2           0.773013  0.10206         False           False           False
# 3           0.773013  0.10206         False           False           False
# 4           0.773013  0.10206         False           False           False
#
#    Company_Aprilia  Company_Arcfox  Company_BMW  Company_Bajaj  \
# 0             True           False        False          False
# 1             True           False        False          False
# 2             True           False        False          False
# 3             True           False        False          False
# 4             True           False        False          False
#
#    Company_Benelli  ...  Engine Type_Single-cylinder, liquid-cooled, 4-stroke  \
# ...
